# %%
import pandas as pd

import seaborn as sns
from matplotlib import pyplot as plt

# %matplotlib inline

# %% [markdown]
# Возьмем датасет [отсюда](https://www.kaggle.com/amanajmera1/framingham-heart-study-dataset).

# %%
df = pd.read_csv("./data/framingham.csv")

# %%
df.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# 2           0
# 3           1
# 4           0

# %%
df.describe()
# Out:
#               male          age    education  currentSmoker   cigsPerDay  \
# count  4240.000000  4240.000000  4135.000000    4240.000000  4211.000000
# mean      0.429245    49.580189     1.979444       0.494104     9.005937
# std       0.495027     8.572942     1.019791       0.500024    11.922462
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    49.000000     2.000000       0.000000     0.000000
# 75%       1.000000    56.000000     3.000000       1.000000    20.000000
# max       1.000000    70.000000     4.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  4187.000000      4240.000000   4240.000000  4240.000000  4190.000000
# mean      0.029615         0.005896      0.310613     0.025708   236.699523
# std       0.169544         0.076569      0.462799     0.158280    44.591284
# min       0.000000         0.000000      0.000000     0.000000   107.000000
# 25%       0.000000         0.000000      0.000000     0.000000   206.000000
# 50%       0.000000         0.000000      0.000000     0.000000   234.000000
# 75%       0.000000         0.000000      1.000000     0.000000   263.000000
# max       1.000000         1.000000      1.000000     1.000000   696.000000
#
#              sysBP        diaBP          BMI    heartRate      glucose  \
# count  4240.000000  4240.000000  4221.000000  4239.000000  3852.000000
# mean    132.354599    82.897759    25.800801    75.878981    81.963655
# std      22.033300    11.910394     4.079840    12.025348    23.954335
# min      83.500000    48.000000    15.540000    44.000000    40.000000
# 25%     117.000000    75.000000    23.070000    68.000000    71.000000
# 50%     128.000000    82.000000    25.400000    75.000000    78.000000
# 75%     144.000000    90.000000    28.040000    83.000000    87.000000
# max     295.000000   142.500000    56.800000   143.000000   394.000000
#
#         TenYearCHD
# count  4240.000000
# mean      0.151887
# std       0.358953
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4240 entries, 0 to 4239
# Data columns (total 16 columns):
# male               4240 non-null int64
# age                4240 non-null int64
# education          4135 non-null float64
# currentSmoker      4240 non-null int64
# cigsPerDay         4211 non-null float64
# BPMeds             4187 non-null float64
# prevalentStroke    4240 non-null int64
# prevalentHyp       4240 non-null int64
# diabetes           4240 non-null int64
# totChol            4190 non-null float64
# sysBP              4240 non-null float64
# diaBP              4240 non-null float64
# BMI                4221 non-null float64
# heartRate          4239 non-null float64
# glucose            3852 non-null float64
# TenYearCHD         4240 non-null int64
# dtypes: float64(9), int64(7)
# memory usage: 530.1 KB

# %%
# что будем делать с NaN-ами?
# что вообще можно с ними делать? (3 варианта)
df = df[~df["education"].isna()]

# %%
df = df[~df["cigsPerDay"].isna()]

# %%
df = df[~df["BPMeds"].isna()]

# %%
df["totChol"] = df["totChol"].fillna(df["totChol"].median())

# %%
df["BMI"] = df["BMI"].fillna(df["BMI"].median())

# %%
df["heartRate"] = df["heartRate"].fillna(df["heartRate"].median())

# %%
df["glucose"] = df["glucose"].fillna(df["glucose"].median())

# %%
# посмотрим на распределения значений признаков (и таргета)

# %%
sns.pairplot(df)

# %%
# посмотрим на корреляцию между признаками

# %%
sns.heatmap(df.corr())

# %%
# посмотрим на "взаимодействия" признаков

# %%
df.drop(['currentSmoker', 'diaBP'], axis = 1, inplace = True)

# %%
sns.heatmap(df.corr())

# %%
# что такое boxplot?
# посмотрим на него (них)

# %%
sns.boxplot(x=df['cigsPerDay'], y=df['male'])

# %%
# выполним нормализацию (зачем она, кстати, нужна)?

# %%
for feature in df.columns:
    plt.title(feature)
    sns.boxplot(x=df["TenYearCHD"], y = df[feature]);
    plt.show();

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df.drop(['TenYearCHD'], axis=1), df['TenYearCHD'],
    test_size=0.33,random_state=42)

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
encoder = OneHotEncoder()

# %%
pd.concat([
    pd.DataFrame(encoder.fit_transform(df['education']).reshape)
    df.drop(['education'], axis=1)
])

# %%
# разделим данные на train и test

# %%
# поработаем с категориальными признаками

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df.drop(['TenYearCHD'], axis=1), df['TenYearCHD'],
    test_size=0.33,random_state=42)

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
pip install lightgbm
# Out:
# Collecting lightgbm
#   Downloading https://files.pythonhosted.org/packages/05/ec/756f13b25258e0aa6ec82d98504e01523814f95fc70718407419b8520e1d/lightgbm-2.3.0-py2.py3-none-manylinux1_x86_64.whl (1.3MB)
#      |████████████████████████████████| 1.3MB 1.4MB/s eta 0:00:01
# Requirement already satisfied: scikit-learn in /home/ilnur/anaconda3/lib/python3.7/site-packages (from lightgbm) (0.21.2)
# Requirement already satisfied: scipy in /home/ilnur/anaconda3/lib/python3.7/site-packages (from lightgbm) (1.3.0)
# Requirement already satisfied: numpy in /home/ilnur/anaconda3/lib/python3.7/site-packages (from lightgbm) (1.16.4)
# Requirement already satisfied: joblib>=0.11 in /home/ilnur/anaconda3/lib/python3.7/site-packages (from scikit-learn->lightgbm) (0.13.2)
# Installing collected packages: lightgbm
# Successfully installed lightgbm-2.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import lightgbm

# %%
model = lightgbm.LGBMClassifier()

# %%
df = df.drop

# %%
model.fit(X_train, y_train)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
from sklearn.metrics import log_loss, roc_auc_score,classification_report

# %%
y_hat = model.predict_proba(X_test)

# %%
print(classification_report(y_test, model.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.97      0.91      1141
#            1       0.36      0.10      0.16       198
#
#     accuracy                           0.84      1339
#    macro avg       0.61      0.53      0.53      1339
# weighted avg       0.79      0.84      0.80      1339

# %%
# обучим модель

# %%
# оценим качество
